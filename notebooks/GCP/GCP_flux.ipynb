# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import sys
sys.path.append('./../../scripts/core')
import GCP_flux as GCPf

# %%
from importlib import reload
reload(GCPf)
# Out:
# <module 'GCP_flux' from './../../scripts/core\\GCP_flux.py'>

# %%
land = GCPf.Analysis("land sink")
ocean = GCPf.Analysis("ocean sink")
land_model = GCPf.Analysis("land sink (model)")

# %%
land.rolling_trend(25, 1)
# Out:
#       25-year trend slope
# Year
# 1959             0.012171
# 1960             0.017787
# 1961             0.006712
# 1962             0.025932
# 1963             0.028022
# 1964             0.012886
# 1965            -0.004896
# 1966            -0.017805
# 1967            -0.027957
# 1968            -0.039718
# 1969            -0.038815
# 1970            -0.029017
# 1971            -0.042946
# 1972            -0.051950
# 1973            -0.025201
# 1974            -0.028582
# 1975            -0.051475
# 1976            -0.052577
# 1977            -0.049959
# 1978            -0.035072
# 1979            -0.048285
# 1980            -0.032745
# 1981            -0.035774
# 1982            -0.040144
# 1983            -0.055567
# 1984            -0.057134
# 1985            -0.058448
# 1986            -0.068166
# 1987            -0.078818
# 1988            -0.057048
# 1989            -0.051937
# 1990            -0.046471
# 1991            -0.042452
# 1992            -0.062636
# ...

# %%
ocean.psd(xlim=[5, 2], plot=1);
# Out:
# C:\Users\Ross\Anaconda3\lib\site-packages\scipy\signal\spectral.py:1969: UserWarning: nperseg = 256 is greater than input length  = 60, using nperseg = 60
#   .format(nperseg, input_length))
# ./../../scripts/core\GCP_flux.py:106: RuntimeWarning: divide by zero encountered in true_divide
#   plt.semilogy(1/freqs, spec)
# ./../../scripts/core\GCP_flux.py:114: RuntimeWarning: divide by zero encountered in true_divide
#   return pd.DataFrame({f"Period{period}": 1/freqs, f"Spectral Variance {unit}": spec}, index=freqs)

# %%
plt.figure(figsize=(14,9))
plt.plot(land.data)
plt.plot(land.data.index, land.bandpass(1/17, btype="low"))

# %%
land.autocorrelation_plot()

# %%
ocean.autocorrelation_plot()
