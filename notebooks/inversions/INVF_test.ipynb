# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pickle
import scipy
from scipy import stats

# %%
import sys
sys.path.append("./../../scripts/core")
import inv_flux as invf

# %%
from importlib import reload

# %%
reload(invf)
# Out:
# <module 'inv_flux' from './../../scripts/core\\inv_flux.py'>

# %%
fCAMS = pickle.load(open("./../../output/inversions/raw/output_all/CAMS_all/year.pik", "rb"))

# %% [markdown]
# # ModelEvaluation

# %%
CAMS = invf.ModelEvaluation(fCAMS)
CAMS.data
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 39)
# Coordinates:
#   * time            (time) object 1979-12-30 00:00:00 ... 2017-12-30 00:00:00
# Data variables:
#     Earth_Land      (time) float64 -0.3236 -0.2909 -1.424 ... -2.248 -3.845
#     South_Land      (time) float64 -0.06017 0.09 0.05536 ... 0.08921 0.08088
#     Tropical_Land   (time) float64 2.072 1.62 0.4356 ... 0.824 0.6507 -1.083
#     North_Land      (time) float64 -2.335 -2.001 -1.915 ... -2.95 -2.988 -2.843
#     Earth_Ocean     (time) float64 -1.054 -1.139 -1.101 ... -1.933 -2.067 -2.189
#     South_Ocean     (time) float64 -0.9933 -1.133 -1.017 ... -1.448 -1.562
#     Tropical_Ocean  (time) float64 0.8567 0.8374 0.8029 ... 0.4387 0.3609 0.3218
#     North_Ocean     (time) float64 -0.9174 -0.8442 -0.8868 ... -0.9797 -0.9491

# %%
CAMS.time;

# %%
CAMS.GCP;

# %%
CAMS.regress_rolling_trend_to_GCP("land", 10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-e9f311c1c2dd> in <module>
# ----> 1 CAMS.regress_rolling_trend_to_GCP("land", 10)
#
# ~\Desktop\Thesis\masters-project\scripts\core\inv_flux.py in regress_rolling_trend_to_GCP(self, sink, window_size, plot)
#     501         GCP = self.GCP
#     502
# --> 503         roll_df = Analysis.rolling_trend(df, model_sink, window_size)
#     504
#     505         return roll_df
#
# ~\Desktop\Thesis\masters-project\scripts\core\inv_flux.py in rolling_trend(self, variable, window_size, plot, include_pearson)
#     224         for i in range(0, len(self.time) - window_size):
#     225             sub_time = self.time[i:i+window_size+1]
# --> 226             sub_vals = self.data[variable].sel(time = slice(self.data.time[i], self.data.time[i+window_size])).values
#     227
#     228             linreg = stats.linregress(to_numeric(sub_time), sub_vals)
#
# ~\Anaconda3\lib\site-packages\xarray\core\common.py in __getattr__(self, name)
#     181                     return source[name]
#     182         raise AttributeError("%r object has no attribute %r" %
# --> 183                              (type(self).__name__, name))
#     184
#     185     def __setattr__(self, name: str, value: Any) -> None:
#
# AttributeError: 'Dataset' object has no attribute 'data'

# %%
CAMS.plot_vs_GCP("land", "time")

# %%
CAMS.regress_timeseries_to_GCP("land", plot=True)
# Out:
# ./../../scripts/core\inv_flux.py:471: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(211).plot(GCP.index, df[model_sink].values)
# LinregressResult(slope=0.8752340489957354, intercept=0.32806285939922675, rvalue=0.9306003663997316, pvalue=9.882157873949554e-18, stderr=0.056595891361134854)

# %%
CAMS.compare_trend_to_GCP("ocean")
# Out:
# {'GCP_slope (MtC/yr)': -25.596381471376514,
#  'Model_slope (MtC/yr)': -23.42924329336258,
#  '%_diff': 9.249714772597343}

# %%
CAMS.autocorrelation_plot("North_Ocean")

# %% [markdown]
# # Analysis

# %%
fmCAMS = pickle.load(open("./../../output/inversions/raw/output_all/CAMS_all/spatial.pik", "rb"))

# %%
reload(invf)
# Out:
# <module 'inv_flux' from './../../scripts/core\\inv_flux.py'>

# %%
aCAMS = invf.Analysis(fmCAMS)
aCAMS.data
# Out:
# <xarray.Dataset>
# Dimensions:         (time: 468)
# Coordinates:
#   * time            (time) object 1979-01-16 00:00:00 ... 2017-12-16 00:00:00
# Data variables:
#     Earth_Land      (time) float64 0.4314 0.5878 0.8693 ... 1.254 1.15 0.4502
#     South_Land      (time) float64 0.03146 0.04228 0.06212 ... -0.03757 0.01857
#     Tropical_Land   (time) float64 -0.3288 0.06462 0.4028 ... 0.2813 -0.3327
#     North_Land      (time) float64 0.7288 0.4809 0.4045 ... 0.7788 0.9061 0.7644
#     Earth_Ocean     (time) float64 -0.09067 -0.09578 ... -0.1494 -0.1669
#     South_Ocean     (time) float64 -0.06071 -0.06981 -0.0825 ... -0.1165 -0.1023
#     Tropical_Ocean  (time) float64 0.0794 0.081 0.09499 ... 0.04063 0.03863
#     North_Ocean     (time) float64 -0.1094 -0.107 -0.1056 ... -0.07353 -0.1032

# %%
aCAMS.time
# Out:
# DatetimeIndex(['1979-01-01', '1979-02-01', '1979-03-01', '1979-04-01',
#                '1979-05-01', '1979-06-01', '1979-07-01', '1979-08-01',
#                '1979-09-01', '1979-10-01',
#                ...
#                '2017-03-01', '2017-04-01', '2017-05-01', '2017-06-01',
#                '2017-07-01', '2017-08-01', '2017-09-01', '2017-10-01',
#                '2017-11-01', '2017-12-01'],
#               dtype='datetime64[ns]', length=468, freq=None)

# %%
aCAMS.rolling_trend("Earth_Land", 10*12, True, True);
# Out:
# C:\Users\Ross\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
mCAMS = invf.Analysis(fCAMS).rolling_trend("Earth_Land", 10, True, True);

# %%
aCAMS.psd("Earth_Ocean", fs=12, xlim=[3,0.5], plot=True)
# Out:
# ./../../scripts/core\inv_flux.py:284: RuntimeWarning: divide by zero encountered in true_divide
#   plt.semilogy(1/freqs, spec)
# ./../../scripts/core\inv_flux.py:292: RuntimeWarning: divide by zero encountered in true_divide
#   return pd.DataFrame({f"Period{period}": 1/freqs, f"Spectral Variance {unit}": spec}, index=freqs)
#           Period (years)  Spectral Variance ((GtC/yr)$^2$.yr)
# 0.000000             inf                             0.000045
# 0.046875       21.333333                             0.000876
# 0.093750       10.666667                             0.001472
# 0.140625        7.111111                             0.000452
# 0.187500        5.333333                             0.000106
# ...                  ...                                  ...
# 5.812500        0.172043                             0.000008
# 5.859375        0.170667                             0.000024
# 5.906250        0.169312                             0.000021
# 5.953125        0.167979                             0.000014
# 6.000000        0.166667                             0.000013
#
# [129 rows x 2 columns]

# %%
aCAMS.deseasonalise("Earth_Land")
# Out:
# array([-8.26732522e-02,  8.66680486e-02,  1.88999076e-01,  9.35715297e-03,
#        -1.11276676e-01, -1.43292989e-01,  1.36718699e-01,  3.18859729e-01,
#        -4.75320959e-02, -1.40050332e-01, -2.64721455e-01, -2.74663682e-01,
#         7.38996238e-02,  2.68021694e-01,  1.91900145e-01,  1.71588427e-01,
#         1.18616802e-01,  2.27583536e-01,  4.78265147e-01, -8.54504094e-02,
#        -7.28895269e-01, -4.12047614e-01, -3.35669383e-01, -2.58686489e-01,
#         7.20556711e-02,  2.26180963e-01, -1.41544831e-01, -5.70036613e-01,
#        -2.83077435e-01,  3.04382726e-01,  1.55726977e-01, -2.46996405e-01,
#        -3.82900716e-01, -3.02027332e-01, -2.16301727e-01, -3.95834563e-02,
#         9.03178097e-02,  4.72797209e-03, -1.59093846e-01, -3.15927810e-01,
#        -2.95682525e-01, -9.29008135e-02, -2.85807049e-01, -2.44948325e-01,
#        -1.92829699e-01, -2.42665515e-01, -3.16589302e-01, -6.54150082e-02,
#         3.10490331e-01,  3.36785179e-01,  2.72546129e-01,  1.31918583e-01,
#         3.86953754e-01,  5.06487227e-01, -9.74399574e-02,  6.80237497e-03,
#        -3.78863764e-01, -5.94535448e-01, -9.94022977e-02,  1.85365296e-01,
#         5.80620864e-02,  1.00289612e-01,  2.55268405e-01, -4.61647968e-02,
#         2.28564785e-03, -6.23972225e-02, -6.49209342e-02, -1.35198523e-01,
#        -4.43737693e-01, -4.06235683e-01, -2.01229772e-01, -7.56416948e-02,
#         1.38340418e-03,  1.87322981e-01,  1.85525533e-01,  4.37654272e-02,
#        -6.68765733e-02,  1.83338943e-02, -1.77687371e-01, -2.16250912e-01,
#        -2.35208811e-01, -2.95395216e-01, -3.19726522e-01, -8.25058326e-02,
#        -3.68970759e-02, -2.03977268e-01, -9.68674286e-02, -4.49128534e-02,
#         2.10727578e-01,  1.54602874e-01, -2.62319648e-01, -1.18779921e-01,
#        -2.19748032e-01, -2.61628085e-01, -3.90255517e-01, -1.93447777e-01,
#         5.74210110e-02,  5.75555427e-02,  1.96339215e-01,  1.39983410e-01,
#         1.01945336e-01,  2.42352876e-01,  1.81449525e-01,  7.30510089e-02,
#        -1.21461620e-01, -1.68758742e-01, -2.76366973e-02,  8.80075763e-04,
#         3.62529925e-02, -1.32011960e-03, -1.76418030e-01, -7.31266115e-02,
#        -6.61985121e-02,  1.24514512e-01,  2.83667458e-01, -8.10112160e-02,
#        -3.12777043e-01, -4.12597954e-01, -2.81308045e-01, -6.06570457e-02,
#        -1.88005007e-01, -2.63248848e-01, -1.48821310e-01, -1.95056380e-01,
#        -2.48405080e-01, -2.20307163e-01, -9.23353718e-02, -4.57092970e-02,
#        -1.95708754e-01, -4.91931004e-01, -3.63551033e-01, -1.03512171e-01,
#        -3.58697590e-03, -2.59924645e-01, -3.16444740e-01, -4.31386056e-02,
#        -1.58839868e-01, -1.69849077e-01, -5.82112887e-02,  8.34554857e-02,
#        -2.00575236e-01, -3.67582082e-01, -3.10738875e-01, -2.39110567e-01,
#        -1.37035815e-01, -6.14709263e-02, -1.67868177e-01, -1.34273644e-01,
#        -1.61473197e-01, -2.40069374e-01, -4.14490653e-01, -5.76830663e-01,
#        -2.21058500e-01, -2.65621293e-01, -2.26303709e-01, -2.81658023e-01,
#        -2.53754895e-01, -3.58591299e-02, -8.18184991e-03, -5.47281707e-02,
#        -2.38736641e-01, -3.73905719e-01, -4.17388070e-01, -5.90828393e-01,
#        -3.34052155e-01, -3.65670412e-01, -1.98643438e-01, -2.01476925e-01,
#        -2.73834632e-01, -3.86668483e-01, -2.31588229e-01, -8.19420835e-02,
#        -2.06107228e-01, -1.94066203e-01, -3.42622426e-01, -2.80118310e-01,
#        -1.31459488e-01, -7.80827647e-02, -2.67762153e-01, -1.54426180e-01,
#        -1.67837068e-01, -2.11300873e-01, -2.71687740e-02, -3.60778196e-02,
#        -2.49462977e-01,  8.56377632e-02,  6.33385235e-02, -1.00990975e-01,
#         4.04377412e-02, -5.75957806e-02, -3.66025821e-02,  1.18102102e-01,
#         5.13815304e-02, -1.57602052e-01, -1.34832542e-01, -9.87978829e-02,
#        -1.45719744e-01, -9.32041792e-02,  1.57449542e-01, -7.67820334e-02,
#        -9.07961834e-02,  4.45593862e-02, -1.60752264e-01, -1.14887891e-01,
#        -3.41765633e-01, -4.20230322e-01, -3.32623757e-01, -3.58168769e-02,
#         5.23657720e-02, -1.11904726e-01, -2.82833798e-01, -4.38579937e-01,
#        -3.74996212e-01, -1.97282946e-01, -2.04884067e-01, -1.85322544e-01,
#        -1.40178274e-01, -1.95602706e-01, -2.90408533e-01, -3.03881615e-01,
#        -2.95069152e-01, -3.20824209e-01, -8.63414870e-02,  3.20958202e-02,
#         5.01127547e-01,  3.13014962e-01,  7.43861575e-02, -7.92141301e-02,
#        -1.31892133e-01, -8.81112720e-02,  1.18761066e-01,  3.74376066e-01,
#         1.55412883e-01,  9.83354845e-02,  2.03342729e-01,  1.26736552e-01,
#        -2.21710171e-01, -2.25810585e-01, -2.83617422e-01, -3.32343312e-01,
#        -3.04721154e-01, -2.00860104e-01, -1.42852461e-01, -4.34579177e-01,
#        -1.92463332e-01, -1.26504106e-01, -4.15046848e-01, -6.33871503e-02,
#        -7.12038359e-02, -1.07714946e-01, -1.72578322e-01, -3.02548999e-01,
#        -4.01675072e-01, -3.29772033e-01, -3.21758975e-01, -2.00389989e-01,
#        -2.92962806e-01, -6.03633469e-02,  1.33040405e-01, -1.33254306e-01,
#         5.79292016e-02, -8.51395022e-02, -2.28924842e-01, -2.52199183e-01,
#        -1.89043418e-01, -3.06276346e-01, -3.80850589e-01, -2.90080002e-01,
#        -2.37223238e-01, -3.49077663e-01,  9.74848787e-02,  9.03894344e-02,
#        -2.62115438e-02, -1.29388882e-01, -1.27819643e-01, -2.09201915e-01,
#        -9.64065232e-02, -2.27033023e-02, -1.82183069e-01, -1.80670580e-01,
#        -2.07271694e-01,  1.15340840e-02,  2.57977884e-01, -5.67595485e-02,
#         6.99920914e-02,  1.53563837e-01, -5.67242305e-02, -1.46700137e-01,
#        -8.67147269e-02,  1.50891553e-02, -2.02340695e-01, -1.93734168e-01,
#         3.50508484e-02,  1.15512154e-02, -2.26649781e-01, -2.75195454e-02,
#        -2.24436601e-01,  4.65103640e-02, -2.19524014e-01, -2.54036605e-01,
#        -1.27826178e-01, -1.76439804e-01, -3.89871244e-01, -3.97215736e-01,
#        -2.80241524e-01, -3.82077714e-01, -6.28134251e-01, -6.78410978e-01,
#        -7.59745353e-02,  1.25687317e-01, -2.27123632e-02, -2.20309857e-01,
#        -1.82702360e-01, -8.15120082e-02, -5.83671923e-02, -2.72284771e-01,
#        -6.69428070e-02, -3.16075574e-01, -3.54664908e-01, -1.12529889e-01,
#        -8.67040689e-02,  5.88840367e-02, -3.02468601e-02, -1.98771947e-01,
#        -1.36446517e-01, -2.49874753e-01, -4.00555622e-01, -3.87709708e-01,
#        -2.66884403e-01, -3.23439307e-01, -2.89413993e-01, -5.38717675e-02,
#        -2.17911302e-01, -1.56107699e-01, -2.51068877e-01, -2.71589395e-01,
#        -1.35687951e-01, -1.88290690e-01, -1.73582782e-01, -3.55047667e-01,
#        -2.16332168e-01, -3.62780942e-01, -2.27897843e-01, -2.04547230e-01,
#        -1.78052358e-02, -2.16502757e-01, -8.15140873e-03, -2.76622702e-02,
#        -4.84661614e-01, -4.55216137e-01, -3.18111858e-01, -2.28296362e-01,
#        -4.06298751e-01, -5.04779716e-01, -6.54596298e-04, -2.63963284e-01,
#        -4.93279319e-01, -3.21980841e-01,  1.80086537e-03, -4.69245666e-02,
#        -4.38765531e-01, -5.06534681e-01, -4.34697820e-01, -2.00145126e-01,
#        -2.83669744e-01, -5.25916112e-01, -4.30262119e-01, -1.86706166e-01,
#        -1.62058227e-01, -2.29360998e-01, -2.20343738e-02,  1.18861018e-01,
#        -2.55625149e-01, -2.22746794e-01, -2.60170734e-01, -2.68912567e-01,
#        -1.85721870e-01, -3.76831450e-01, -2.25924954e-01, -2.50139068e-01,
#        -1.91005700e-02, -1.93771511e-01, -1.17931974e-01, -2.28169278e-01,
#        -4.30092852e-01, -6.34850616e-01, -5.00343326e-01, -2.29339299e-01,
#        -1.09602001e-01, -3.33109133e-01, -2.75053018e-01, -2.87899117e-01,
#        -1.29591074e-01, -7.40272991e-02, -4.21742129e-01, -3.81281777e-01,
#        -1.98504728e-01, -2.63215979e-01, -4.84199823e-01, -2.25785255e-01,
#        -3.60376649e-01, -2.02461836e-01, -2.49705914e-01,  3.34289458e-02,
#         2.54178255e-02,  1.42892033e-02, -1.27221686e-01, -1.83613352e-01,
#        -1.32183918e-01, -1.56414716e-01,  7.47252742e-03, -1.72095035e-01,
#        -2.37037177e-01, -2.82966293e-01, -6.03516620e-01, -4.13975746e-01,
#        -1.39161839e-01, -1.98021373e-01, -9.05105481e-02, -4.05614337e-01,
#        -6.05374830e-01, -4.00210566e-01, -1.97908697e-01, -3.23113986e-01,
#        -3.62434648e-01, -2.85118244e-01, -3.78589735e-01, -1.81117753e-01,
#        -3.59029662e-01, -7.11882700e-03, -8.18984401e-02, -2.63076152e-01,
#        -4.50143300e-01, -3.55813025e-01, -3.40263534e-01, -3.05395978e-01,
#        -3.13094180e-01, -4.24331329e-01, -4.88491866e-01, -1.48875056e-01,
#         1.35270834e-01,  2.82673996e-01,  3.73341016e-01,  1.19005223e-01,
#         1.76977800e-02, -1.43089997e-01, -1.76476112e-01, -1.50359401e-01,
#        -2.34207610e-01, -6.70011028e-01, -4.96684944e-01, -1.50776173e-01,
#         2.54409749e-02, -7.48152914e-02,  1.48445449e-02, -2.09416419e-01,
#        -4.96490619e-01, -4.45067917e-01, -3.61980479e-01, -1.63517462e-01,
#        -4.25233374e-01, -3.78315689e-01, -4.16937286e-01, -4.54176217e-01,
#        -1.40401921e-01, -1.01279352e-01, -1.21151575e-01, -3.40109759e-01])

# %%
plt.figure(figsize=(22,10))
plt.plot(aCAMS.time, aCAMS.deseasonalise("Earth_Land"))
plt.plot(aCAMS.time, aCAMS.bandpass("Earth_Land", 1/(10*12), deseasonalise_first=True))

# %% [markdown]
# # Rolling gradient functions

# %%
aCAMS.data.time[0]
# Out:
# <xarray.DataArray 'time' ()>
# array(cftime.Datetime360Day(1979, 1, 16, 0, 0, 0, 0, 2, 16), dtype=object)
# Coordinates:
#     time     object 1979-01-16 00:00:00

# %%
aCAMS.data["Earth_Land"].sel(time=slice(CAMS.data.time[0], CAMS.data.time[0+10]))
# Out:
# <xarray.DataArray 'Earth_Land' (time: 120)>
# array([ 0.587993,  0.769167,  0.872226,  0.607813, -0.435116, -1.539517,
#        -1.918248, -1.257281, -0.388206,  0.943316,  0.935349,  0.53163 ,
#         0.586149,  0.727326,  0.538781, -0.133812, -0.83681 , -1.462718,
#        -2.240786, -1.418827, -0.042211,  1.053336,  1.054717,  0.750733,
#         0.604411,  0.505873,  0.521232,  0.120297, -0.849416, -1.860001,
#        -2.68232 , -1.416779,  0.14786 ,  1.112698,  0.95443 ,  0.724901,
#         0.824584,  0.837931,  0.952872,  0.568143, -0.166779, -1.260613,
#        -2.493953, -1.165028, -0.038174,  0.760828,  1.171617,  0.975682,
#         0.572155,  0.601435,  0.935594,  0.39006 , -0.551447, -1.829498,
#        -2.461434, -1.307029, -0.103048,  0.949128,  1.069789,  0.714675,
#         0.515477,  0.688468,  0.865851,  0.47999 , -0.62061 , -1.748766,
#        -2.574201, -1.388081,  0.105481,  1.059969,  0.951292,  0.707811,
#         0.477196,  0.297168,  0.583458,  0.391312, -0.343005, -1.612497,
#        -2.658833, -1.29061 ,  0.120941,  1.093736,  0.880763,  0.596869,
#         0.571514,  0.558701,  0.876665,  0.576208, -0.451788, -1.524747,
#        -2.215064, -1.09878 ,  0.219228,  1.186605,  1.243382,  0.791196,
#         0.550346,  0.499825,  0.503908,  0.363098, -0.619932, -1.642586,
#        -2.112846, -1.252842,  0.027912,  0.942766,  0.989711,  0.729659,
#         0.326088,  0.237897,  0.531504,  0.241168, -0.802138, -1.987408,
#        -2.488849, -1.21754 ,  0.144981,  0.863433,  0.907468,  0.686804])
# Coordinates:
#   * time     (time) object 1980-01-16 00:00:00 ... 1989-12-16 00:00:00

# %%
window_size = 20
roll_values = []
for i in range(0, len(aCAMS.time) - window_size):
    timeCAMS = aCAMS.time[i:i+window_size+1]
    subCAMS = aCAMS.data["Earth_Land"].sel(time=slice(aCAMS.data.time[i], aCAMS.data.time[i+window_size])).values
    
    statsCAMS = stats.linregress(timeCAMS.year, subCAMS)
    
    roll_values.append(statsCAMS[0])
    
plt.plot(aCAMS.time[:len(aCAMS.time) - window_size], roll_values)

# %%
f = aCAMS.data["Earth_Land"].sel(time=slice(aCAMS.data.time[0], aCAMS.data.time[0+10])).time.values
f
# Out:
# array([cftime.Datetime360Day(1979, 1, 16, 0, 0, 0, 0, 2, 16),
#        cftime.Datetime360Day(1979, 2, 16, 0, 0, 0, 0, 4, 46),
#        cftime.Datetime360Day(1979, 3, 16, 0, 0, 0, 0, 6, 76),
#        cftime.Datetime360Day(1979, 4, 16, 0, 0, 0, 0, 1, 106),
#        cftime.Datetime360Day(1979, 5, 16, 0, 0, 0, 0, 3, 136),
#        cftime.Datetime360Day(1979, 6, 16, 0, 0, 0, 0, 5, 166),
#        cftime.Datetime360Day(1979, 7, 16, 0, 0, 0, 0, 0, 196),
#        cftime.Datetime360Day(1979, 8, 16, 0, 0, 0, 0, 2, 226),
#        cftime.Datetime360Day(1979, 9, 16, 0, 0, 0, 0, 4, 256),
#        cftime.Datetime360Day(1979, 10, 16, 0, 0, 0, 0, 6, 286),
#        cftime.Datetime360Day(1979, 11, 16, 0, 0, 0, 0, 1, 316)],
#       dtype=object)

# %%
def date(f):
    return f.year + (f.month-1 + f.day/31)/12

# %%
date(CAMS.time)
# Out:
# Float64Index([1979.9193548387098, 1980.9193548387098, 1981.9193548387098,
#               1982.9193548387098, 1983.9193548387098, 1984.9193548387098,
#               1985.9193548387098, 1986.9193548387098, 1987.9193548387098,
#               1988.9193548387098, 1989.9193548387098, 1990.9193548387098,
#               1991.9193548387098, 1992.9193548387098, 1993.9193548387098,
#               1994.9193548387098, 1995.9193548387098, 1996.9193548387098,
#               1997.9193548387098, 1998.9193548387098, 1999.9193548387098,
#               2000.9193548387098, 2001.9193548387098, 2002.9193548387098,
#               2003.9193548387098, 2004.9193548387098, 2005.9193548387098,
#               2006.9193548387098, 2007.9193548387098, 2008.9193548387098,
#               2009.9193548387098, 2010.9193548387098, 2011.9193548387098,
#               2012.9193548387098, 2013.9193548387098, 2014.9193548387098,
#               2015.9193548387098, 2016.9193548387098, 2017.9193548387098],
#              dtype='float64')

# %%
plt.figure(figsize=(22,8))
plt.plot(date(CAMS.time), CAMS.data.Earth_Land)

# %%
plt.figure(figsize=(22,8))
plt.plot(CAMS.time, CAMS.data.Earth_Land)

# %%
f[0].day/365
# Out:
# 0.043835616438356165

# %%
f[0].month/12
# Out:
# 0.08333333333333333

# %%
dir(f[0])
# Out:
# ['__add__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__pyx_vtable__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rsub__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '_to_real_datetime',
#  'calendar',
#  'datetime_compatible',
#  'day',
#  'dayofwk',
#  'dayofyr',
#  'format',
#  'hour',
#  'microsecond',
#  'minute',
#  'month',
#  'replace',
#  'second',
#  'strftime',
#  'timetuple',
#  'year']
