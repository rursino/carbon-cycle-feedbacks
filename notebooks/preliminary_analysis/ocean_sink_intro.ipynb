# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('./../gcb_data/ocean_sink.csv')
df.head()
# Out:
#    year       GCB  CCSM-BEC  MITgcm-REcoM2  MPIOM-HAMOCC  \
# 0  1959  0.852376  1.028331           0.43        0.8360
# 1  1960  0.819017  0.814816           0.57        0.7934
# 2  1961  0.714842  0.722197           0.43        0.7879
# 3  1962  0.756709  0.686463           0.58        0.7508
# 4  1963  0.904997  0.820377           0.71        0.8148
#
#    NEMO3.6-PISCESv2-gas (CNRM)  NEMO-PISCES (IPSL)  NEMO-PlankTOM5  NorESM-OC  \
# 0                         1.11               0.498           0.886     1.1783
# 1                         0.98               0.507           0.919     1.1489
# 2                         0.70               0.414           0.877     1.0728
# 3                         0.67               0.382           0.974     1.2537
# 4                         0.87               0.578           1.114     1.4278
#
#    Landschützer  Rödenbeck
# 0           NaN        NaN
# 1           NaN        NaN
# 2           NaN        NaN
# 3           NaN        NaN
# ...

# %%
year = df['year']

# %%
plt.plot(year, df['GCB'])

# %%
df.shape

# %%
for i in range(2,df.shape[1]):
    column = df.iloc[:,i]
    plt.plot(year, column)
plt.legend()
