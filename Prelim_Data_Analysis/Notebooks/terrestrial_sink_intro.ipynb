# %%
import numpy as np
import pandas as pd
import scipy as sp
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('./../gcb_data/terrestrial_sink.csv')
df.head()
# Out:
#    Year       GCB   CABLE  CLASS-CTEM    CLM5.0      DLEM    ISAM  JSBACH  \
# 0  1959  0.516073  0.4640     -0.1892  1.116680  0.684073  1.1697  0.4809
# 1  1960  1.394030  2.6133      1.2883  1.301660  1.715826  1.4693  2.0734
# 2  1961  0.605098  1.8724      1.1669  0.374898  0.467183  0.8829  1.6108
# 3  1962  1.348349  2.1697      1.9863  1.050040  1.088284  1.4048  2.2852
# 4  1963  0.877794  1.9296      0.2003  0.748967  0.570187  1.0754  1.5373
#
#       JULES  LPJ-GUESS       LPJ   LPX-Bern       OCN  ORCHIDEE-CNP  \
# 0  1.093846   -0.057435 -0.539566  0.058524  1.040683      0.206038
# 1  1.146827    1.452678  0.460055  0.867830  1.085341      1.223100
# 2  0.974819   -0.137858 -0.635602 -0.285865  1.296894     -0.003089
# 3  2.097593    1.143677  0.267879 -0.045862  1.776678      1.424690
# 4  1.946781   -0.715668 -0.523421 -0.172822  1.569486      0.185551
#
#    ORCHIDEE-Trunk     SDGVM   SURFEX  VISIT
# 0        0.517777  0.144951  0.81120  1.255
# ...

# %%
year = df['Year']

# %%
plt.plot(year, df['GCB'])

# %%
df.shape
# Out:
# (59, 18)

# %%
for i in range(2,df.shape[1]):
    column = df.iloc[:,i]
    plt.plot(year, column)
plt.legend()
